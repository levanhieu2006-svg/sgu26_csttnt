# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile MADITUAN.INP
# 5 2 2
# Out:
# Overwriting MADITUAN.INP

# %%
# %run madituan.py - --action test1
# Out:
# 1
# 19 2 13 8 25
# 12 7 18 3 14
# 17 20 1 24 9
# 6 11 22 15 4
# 21 16 5 10 23

# %%
# %run madituan.py - --action main
# Out:
# 1
# 19 2 13 8 25
# 12 7 18 3 14
# 17 20 1 24 9
# 6 11 22 15 4
# 21 16 5 10 23

# %%
# %run madituan.py - --action main --file MADITUAN.INP
# Out:
# 1
# 19 2 13 8 25
# 12 7 18 3 14
# 17 20 1 24 9
# 6 11 22 15 4
# 21 16 5 10 23
