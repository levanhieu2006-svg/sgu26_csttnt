# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%writefile SUDOKU.INP
# .....2.3.
# 374..6.2.
# .....8.1.
# 258......
# .........
# ......493
# .4.1.....
# .2.8..675
# .6.5.....
# Out:
# Writing SUDOKU.INP

# %%
# %run sudoku.py
# Out:
# 185742936
# 374916528
# 692358714
# 258493167
# 439671852
# 716285493
# 543167289
# 921834675
# 867529341
