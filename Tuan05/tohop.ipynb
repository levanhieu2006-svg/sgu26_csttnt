# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%writefile TOHOP.INP
# 5 3
# A
# B
# C
# D
# E
# Out:
# Overwriting TOHOP.INP

# %%
# %run ToHop.py - --action test1
# Out:
# ----- DOC FILE -----
# n = 5, k = 3, th = ['A', 'B', 'C', 'D', 'E']
# Ket qua:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %%writefile TOHOP.IN1
# 3 2
# F
# B
# A
# Out:
# Writing TOHOP.IN1

# %%
# %run ToHop.py - --action main --file TOHOP.IN1
# Out:
# 3
# F B
# F A
# B A
