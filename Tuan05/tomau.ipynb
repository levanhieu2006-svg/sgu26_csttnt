# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile TOMAU.INP
# 9
# 1 2
# 1 4
# 1 5
# 2 3
# 3 4
# 3 7
# 4 5
# 4 6
# 5 6
# 5 9
# 6 8
# 6 9
# Out:
# Writing TOMAU.INP

# %%
# %run tomau.py
# Out:
# 3
# 2 4 7 8 9
# 3 5
# 1 6
